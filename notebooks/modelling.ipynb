# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from pyspark.sql import SparkSession

# Create a spark session (which will run spark jobs)
spark = (
    SparkSession.builder.appName("MAST30034 Project 1")
    .config("spark.sql.repl.eagerEval.enabled", True) 
    .config("spark.sql.parquet.cacheMetadata", "true")
    .config("spark.sql.session.timeZone", "Etc/UTC") # fix timestamps loaded by spark
    .getOrCreate()
)
# Out:
# your 131072x1 screen size is bogus. expect trouble
# 23/08/08 13:53:38 WARN Utils: Your hostname, DESKTOP-SATV84A resolves to a loopback address: 127.0.1.1; using 172.26.254.29 instead (on interface eth0)
# 23/08/08 13:53:38 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 23/08/08 13:53:39 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# # Modelling

# %% [markdown]
# ### Outlier analysis, discussion of the distribution, relevant imputations for NULL values, and summarsed findings of interest for the attributes

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#df = spark.read.parquet('../data/curated/combined.parquet')

df = pd.read_parquet('../data/curated/combined_imputed.parquet')

# %%
# train separate model for airport zones where external columns are dropped as they are irrelevant to airport zones

# use folium map to show predicted zone profitability vs actual

# %%
df.head()
# Out:
#    locationid  year  month  day_of_month  hour  day_of_week  \
# 0         237  2022      5            12    18            5
# 1         237  2022      5             4    18            4
# 2         237  2022      5            17    17            3
# 3         161  2022      5             4    19            4
# 4         161  2022      5            10    19            3
#
#    avg_usd_per_1/5_mile  avg_usd_per_minute  number_of_trips_here  is_weekday  \
# 0              2.237502            1.596395                   258        True
# 1              2.303215            1.656734                   249        True
# 2              2.749652            1.522721                   229        True
# 3              1.986236            1.531835                   278        True
# 4              1.989695            1.438527                   285        True
#
#    is_public_holiday  number_of_trips_nyc  zone_profitability  \
# 0              False                 3995          989.145415
# 1              False                 3983          986.027285
# 2              False                 3094          978.373302
# 3              False                 3452          978.023633
# 4              False                 3386          977.043139
#
#    number_of_airbnb_here  avg_daily_airbnb_price_usd  number_of_hotels_here  \
# 0                   82.0                  585.414634                   17.0
# 1                   82.0                  585.414634                   17.0
# 2                   82.0                  585.414634                   17.0
# 3                  150.0                  592.800000                   82.0
# 4                  150.0                  592.800000                   82.0
#
#    number_of_parking_munimeters_here  number_of_subway_stations_here  \
# 0                              181.0                             5.0
# 1                              181.0                             5.0
# 2                              181.0                             5.0
# 3                              145.0                             2.0
# 4                              145.0                             2.0
#
#    total_pop  avg_income_per_cap  poverty_%  professional_%  service_%  \
# 0    19408.0       170575.666667   4.733333       76.816667      3.350
# 1    19408.0       170575.666667   4.733333       76.816667      3.350
# 2    19408.0       170575.666667   4.733333       76.816667      3.350
# 3     1404.0        95716.250000   6.025000       64.925000     18.075
# 4     1404.0        95716.250000   6.025000       64.925000     18.075
#
#     office_%  construction_%  production_%    drive_%  carpool_%  transit_%  \
# 0  18.333333            0.75          0.75  12.183333       2.25     30.750
# 1  18.333333            0.75          0.75  12.183333       2.25     30.750
# 2  18.333333            0.75          0.75  12.183333       2.25     30.750
# 3  10.275000            5.40          1.30   4.250000       0.00     21.975
# 4  10.275000            5.40          1.30   4.250000       0.00     21.975
#
#    walk_%  work_at_home_%  avg_commute_mins  private_work_%  public_work_%  \
# 0   30.70       12.916667             23.15       82.266667       5.333333
# 1   30.70       12.916667             23.15       82.266667       5.333333
# 2   30.70       12.916667             23.15       82.266667       5.333333
# 3   52.85       12.875000             40.25       87.650000       2.925000
# 4   52.85       12.875000             40.25       87.650000       2.925000
#
#    self_employed_%  unemployment_%
# 0           11.450           3.450
# 1           11.450           3.450
# 2           11.450           3.450
# 3            9.425           2.575
# 4            9.425           2.575

# %%
df.columns
# Out:
# Index(['locationid', 'year', 'month', 'day_of_month', 'hour', 'day_of_week',
#        'avg_usd_per_1/5_mile', 'avg_usd_per_minute', 'number_of_trips_here',
#        'is_weekday', 'is_public_holiday', 'number_of_trips_nyc',
#        'zone_profitability', 'number_of_airbnb_here',
#        'avg_daily_airbnb_price_usd', 'number_of_hotels_here',
#        'number_of_parking_munimeters_here', 'number_of_subway_stations_here',
#        'total_pop', 'avg_income_per_cap', 'poverty_%', 'professional_%',
#        'service_%', 'office_%', 'construction_%', 'production_%', 'drive_%',
#        'carpool_%', 'transit_%', 'walk_%', 'work_at_home_%',
#        'avg_commute_mins', 'private_work_%', 'public_work_%',
#        'self_employed_%', 'unemployment_%'],
#       dtype='object')

# %% [markdown]
# ### Check relationship between attributes of interest and miscellaneous external factors

# %%
CORR_COLS = [
    #"month", "day_of_month", "hour","day_of_week", 
    "avg_usd_per_1/5_mile", "avg_usd_per_minute",
    "number_of_trips_here", "is_weekday", "is_public_holiday", "number_of_airbnb_here", "avg_daily_airbnb_price_usd", "number_of_hotels_here", "number_of_subway_stations_here", 
    "number_of_parking_munimeters_here", "zone_profitability"
]

pd.set_option('display.max_columns', None)

df[CORR_COLS].corr()
# Out:
#                                    avg_usd_per_1/5_mile  avg_usd_per_minute  \
# avg_usd_per_1/5_mile                           1.000000            0.352276
# avg_usd_per_minute                             0.352276            1.000000
# number_of_trips_here                           0.272586           -0.073944
# is_weekday                                     0.076591           -0.048714
# is_public_holiday                             -0.023628            0.034910
# number_of_airbnb_here                          0.064576           -0.034558
# avg_daily_airbnb_price_usd                     0.195614           -0.000724
# number_of_hotels_here                          0.095268            0.024038
# number_of_subway_stations_here                 0.006957           -0.048566
# number_of_parking_munimeters_here              0.179045            0.053373
# zone_profitability                             0.318874           -0.048959
#
#                                    number_of_trips_here  is_weekday  \
# avg_usd_per_1/5_mile                           0.272586    0.076591
# avg_usd_per_minute                            -0.073944   -0.048714
# number_of_trips_here                           1.000000    0.051854
# is_weekday                                     0.051854    1.000000
# is_public_holiday                             -0.035339    0.057094
# number_of_airbnb_here                          0.023557   -0.014864
# avg_daily_airbnb_price_usd                     0.267045    0.015872
# number_of_hotels_here                          0.151971    0.008695
# number_of_subway_stations_here                 0.000469   -0.005814
# number_of_parking_munimeters_here              0.304235    0.007000
# zone_profitability                             0.987927    0.061268
#
#                                    is_public_holiday  number_of_airbnb_here  \
# avg_usd_per_1/5_mile                       -0.023628               0.064576
# avg_usd_per_minute                          0.034910              -0.034558
# number_of_trips_here                       -0.035339               0.023557
# is_weekday                                  0.057094              -0.014864
# is_public_holiday                           1.000000               0.003666
# number_of_airbnb_here                       0.003666               1.000000
# avg_daily_airbnb_price_usd                 -0.000193              -0.100000
# number_of_hotels_here                       0.000797              -0.033771
# number_of_subway_stations_here             -0.000109               0.076149
# number_of_parking_munimeters_here           0.000857               0.410696
# zone_profitability                         -0.034628               0.035461
#
#                                    avg_daily_airbnb_price_usd  \
# avg_usd_per_1/5_mile                                 0.195614
# avg_usd_per_minute                                  -0.000724
# number_of_trips_here                                 0.267045
# is_weekday                                           0.015872
# is_public_holiday                                   -0.000193
# number_of_airbnb_here                               -0.100000
# avg_daily_airbnb_price_usd                           1.000000
# number_of_hotels_here                                0.276150
# number_of_subway_stations_here                       0.305528
# number_of_parking_munimeters_here                    0.199829
# zone_profitability                                   0.286324
#
#                                    number_of_hotels_here  \
# avg_usd_per_1/5_mile                            0.095268
# avg_usd_per_minute                              0.024038
# number_of_trips_here                            0.151971
# is_weekday                                      0.008695
# is_public_holiday                               0.000797
# number_of_airbnb_here                          -0.033771
# avg_daily_airbnb_price_usd                      0.276150
# number_of_hotels_here                           1.000000
# number_of_subway_stations_here                 -0.046570
# number_of_parking_munimeters_here               0.032529
# zone_profitability                              0.158461
#
#                                    number_of_subway_stations_here  \
# avg_usd_per_1/5_mile                                     0.006957
# avg_usd_per_minute                                      -0.048566
# number_of_trips_here                                     0.000469
# is_weekday                                              -0.005814
# is_public_holiday                                       -0.000109
# number_of_airbnb_here                                    0.076149
# avg_daily_airbnb_price_usd                               0.305528
# number_of_hotels_here                                   -0.046570
# number_of_subway_stations_here                           1.000000
# number_of_parking_munimeters_here                        0.362220
# zone_profitability                                       0.002844
#
#                                    number_of_parking_munimeters_here  \
# avg_usd_per_1/5_mile                                        0.179045
# avg_usd_per_minute                                          0.053373
# number_of_trips_here                                        0.304235
# is_weekday                                                  0.007000
# is_public_holiday                                           0.000857
# number_of_airbnb_here                                       0.410696
# avg_daily_airbnb_price_usd                                  0.199829
# number_of_hotels_here                                       0.032529
# number_of_subway_stations_here                              0.362220
# number_of_parking_munimeters_here                           1.000000
# zone_profitability                                          0.335629
#
#                                    zone_profitability
# avg_usd_per_1/5_mile                         0.318874
# avg_usd_per_minute                          -0.048959
# number_of_trips_here                         0.987927
# is_weekday                                   0.061268
# is_public_holiday                           -0.034628
# number_of_airbnb_here                        0.035461
# avg_daily_airbnb_price_usd                   0.286324
# number_of_hotels_here                        0.158461
# number_of_subway_stations_here               0.002844
# number_of_parking_munimeters_here            0.335629
# zone_profitability                           1.000000

# %%
sns.heatmap(df[CORR_COLS].corr())


plt.title('Pearson Correlation Metric for Miscellaneous Factors')
plt.show()

# %%
# look at why parking_munimeters correlates with zone profitability (airbnb price and incomepercap likely correlate with zone profitability as they would correlate with richer areas / more densely populated areas)

# %% [markdown]
# ### Check relationship between attributes of interest and job type

# %%
CORR_COLS = [
    #"month", "day_of_month", "hour","day_of_week", 
    "avg_usd_per_1/5_mile", "avg_usd_per_minute",
    "number_of_trips_here", 'total_pop', 'avg_income_per_cap', 'poverty_%', 'professional_%',
    'service_%', 'office_%', 'construction_%', 'production_%',
    'zone_profitability'
]

pd.set_option('display.max_columns', None)

df[CORR_COLS].corr()
# Out:
#                       avg_usd_per_1/5_mile  avg_usd_per_minute  \
# avg_usd_per_1/5_mile              1.000000            0.352276
# avg_usd_per_minute                0.352276            1.000000
# number_of_trips_here              0.272586           -0.073944
# total_pop                        -0.053186            0.015698
# avg_income_per_cap                0.258625            0.068702
# poverty_%                        -0.086817           -0.054763
# professional_%                    0.252562            0.040717
# service_%                        -0.241461           -0.060547
# office_%                         -0.074849            0.017687
# construction_%                   -0.248727           -0.007341
# production_%                     -0.245761           -0.043066
# zone_profitability                0.318874           -0.048959
#
#                       number_of_trips_here  total_pop  avg_income_per_cap  \
# avg_usd_per_1/5_mile              0.272586  -0.053186            0.258625
# avg_usd_per_minute               -0.073944   0.015698            0.068702
# number_of_trips_here              1.000000  -0.150540            0.411478
# total_pop                        -0.150540   1.000000           -0.369431
# avg_income_per_cap                0.411478  -0.369431            1.000000
# poverty_%                        -0.179951   0.097851           -0.640769
# professional_%                    0.293220  -0.377620            0.812020
# service_%                        -0.302809   0.403803           -0.835412
# office_%                         -0.094389   0.205417           -0.219212
# construction_%                   -0.230937   0.237321           -0.658642
# production_%                     -0.312844   0.348050           -0.780777
# zone_profitability                0.987927  -0.127165            0.442055
#
#                       poverty_%  professional_%  service_%  office_%  \
# avg_usd_per_1/5_mile  -0.086817        0.252562  -0.241461 -0.074849
# avg_usd_per_minute    -0.054763        0.040717  -0.060547  0.017687
# number_of_trips_here  -0.179951        0.293220  -0.302809 -0.094389
# total_pop              0.097851       -0.377620   0.403803  0.205417
# avg_income_per_cap    -0.640769        0.812020  -0.835412 -0.219212
# poverty_%              1.000000       -0.602866   0.600683  0.281175
# professional_%        -0.602866        1.000000  -0.956786 -0.498913
# service_%              0.600683       -0.956786   1.000000  0.297161
# office_%               0.281175       -0.498913   0.297161  1.000000
# construction_%         0.391874       -0.812467   0.764112  0.174774
# production_%           0.546047       -0.929721   0.875916  0.358249
# zone_profitability    -0.190460        0.319978  -0.325134 -0.107541
#
#                       construction_%  production_%  zone_profitability
# avg_usd_per_1/5_mile       -0.248727     -0.245761            0.318874
# avg_usd_per_minute         -0.007341     -0.043066           -0.048959
# number_of_trips_here       -0.230937     -0.312844            0.987927
# total_pop                   0.237321      0.348050           -0.127165
# avg_income_per_cap         -0.658642     -0.780777            0.442055
# poverty_%                   0.391874      0.546047           -0.190460
# professional_%             -0.812467     -0.929721            0.319978
# service_%                   0.764112      0.875916           -0.325134
# office_%                    0.174774      0.358249           -0.107541
# construction_%              1.000000      0.775612           -0.253043
# production_%                0.775612      1.000000           -0.335272
# zone_profitability         -0.253043     -0.335272            1.000000

# %%
sns.heatmap(df[CORR_COLS].corr())


plt.title('Pearson Correlation Metric For Job Type')
plt.show()

# %% [markdown]
# ### Check relationship between attributes of interest and transport preferences

# %%
CORR_COLS = [
    #"month", "day_of_month", "hour","day_of_week", 
    "avg_usd_per_1/5_mile", "avg_usd_per_minute",
    "number_of_trips_here", 'total_pop', 'avg_income_per_cap', 'drive_%',
       'carpool_%', 'transit_%', 'walk_%', 'work_at_home_%',
       'avg_commute_mins', 'zone_profitability'
]

pd.set_option('display.max_columns', None)

df[CORR_COLS].corr()
# Out:
#                       avg_usd_per_1/5_mile  avg_usd_per_minute  \
# avg_usd_per_1/5_mile              1.000000            0.352276
# avg_usd_per_minute                0.352276            1.000000
# number_of_trips_here              0.272586           -0.073944
# total_pop                        -0.053186            0.015698
# avg_income_per_cap                0.258625            0.068702
# drive_%                          -0.213156            0.061190
# carpool_%                        -0.201875            0.025580
# transit_%                        -0.197311           -0.077612
# walk_%                            0.252252            0.040879
# work_at_home_%                    0.111790           -0.019213
# avg_commute_mins                 -0.264774           -0.022227
# zone_profitability                0.318874           -0.048959
#
#                       number_of_trips_here  total_pop  avg_income_per_cap  \
# avg_usd_per_1/5_mile              0.272586  -0.053186            0.258625
# avg_usd_per_minute               -0.073944   0.015698            0.068702
# number_of_trips_here              1.000000  -0.150540            0.411478
# total_pop                        -0.150540   1.000000           -0.369431
# avg_income_per_cap                0.411478  -0.369431            1.000000
# drive_%                          -0.142306   0.197608           -0.400757
# carpool_%                        -0.177071   0.225323           -0.422730
# transit_%                        -0.398670   0.508977           -0.537319
# walk_%                            0.339580  -0.437741            0.507994
# work_at_home_%                    0.213980  -0.160270            0.461691
# avg_commute_mins                 -0.269046   0.410377           -0.739494
# zone_profitability                0.987927  -0.127165            0.442055
#
#                        drive_%  carpool_%  transit_%    walk_%  \
# avg_usd_per_1/5_mile -0.213156  -0.201875  -0.197311  0.252252
# avg_usd_per_minute    0.061190   0.025580  -0.077612  0.040879
# number_of_trips_here -0.142306  -0.177071  -0.398670  0.339580
# total_pop             0.197608   0.225323   0.508977 -0.437741
# avg_income_per_cap   -0.400757  -0.422730  -0.537319  0.507994
# drive_%               1.000000   0.719311   0.115166 -0.529470
# carpool_%             0.719311   1.000000   0.134996 -0.418660
# transit_%             0.115166   0.134996   1.000000 -0.838293
# walk_%               -0.529470  -0.418660  -0.838293  1.000000
# work_at_home_%       -0.310790  -0.345454  -0.261146  0.140934
# avg_commute_mins      0.671320   0.533115   0.475440 -0.681956
# zone_profitability   -0.158369  -0.190736  -0.407746  0.356710
#
#                       work_at_home_%  avg_commute_mins  zone_profitability
# avg_usd_per_1/5_mile        0.111790         -0.264774            0.318874
# avg_usd_per_minute         -0.019213         -0.022227           -0.048959
# number_of_trips_here        0.213980         -0.269046            0.987927
# total_pop                  -0.160270          0.410377           -0.127165
# avg_income_per_cap          0.461691         -0.739494            0.442055
# drive_%                    -0.310790          0.671320           -0.158369
# carpool_%                  -0.345454          0.533115           -0.190736
# transit_%                  -0.261146          0.475440           -0.407746
# walk_%                      0.140934         -0.681956            0.356710
# work_at_home_%              1.000000         -0.225624            0.234828
# avg_commute_mins           -0.225624          1.000000           -0.290616
# zone_profitability          0.234828         -0.290616            1.000000

# %%
sns.heatmap(df[CORR_COLS].corr())


plt.title('Pearson Correlation Metric For Transportation Preferences')
plt.show()

# %% [markdown]
# ### Check relationship between attributes of interest and type of employment

# %%
CORR_COLS = [
    #"month", "day_of_month", "hour","day_of_week", 
    "avg_usd_per_1/5_mile", "avg_usd_per_minute",
    "number_of_trips_here", 'total_pop', 'avg_income_per_cap', 'private_work_%', 'public_work_%',
       'self_employed_%', 'unemployment_%', 'zone_profitability'
]

pd.set_option('display.max_columns', None)

df[CORR_COLS].corr()
# Out:
#                       avg_usd_per_1/5_mile  avg_usd_per_minute  \
# avg_usd_per_1/5_mile              1.000000            0.352276
# avg_usd_per_minute                0.352276            1.000000
# number_of_trips_here              0.272586           -0.073944
# total_pop                        -0.053186            0.015698
# avg_income_per_cap                0.258625            0.068702
# private_work_%                    0.198867            0.055312
# public_work_%                    -0.244738           -0.051407
# self_employed_%                   0.115967           -0.011580
# unemployment_%                   -0.024897           -0.009250
# zone_profitability                0.318874           -0.048959
#
#                       number_of_trips_here  total_pop  avg_income_per_cap  \
# avg_usd_per_1/5_mile              0.272586  -0.053186            0.258625
# avg_usd_per_minute               -0.073944   0.015698            0.068702
# number_of_trips_here              1.000000  -0.150540            0.411478
# total_pop                        -0.150540   1.000000           -0.369431
# avg_income_per_cap                0.411478  -0.369431            1.000000
# private_work_%                    0.247513  -0.455893            0.549244
# public_work_%                    -0.353595   0.455274           -0.690814
# self_employed_%                   0.206234  -0.001008            0.325816
# unemployment_%                   -0.044742  -0.024061           -0.382300
# zone_profitability                0.987927  -0.127165            0.442055
#
#                       private_work_%  public_work_%  self_employed_%  \
# avg_usd_per_1/5_mile        0.198867      -0.244738         0.115967
# avg_usd_per_minute          0.055312      -0.051407        -0.011580
# number_of_trips_here        0.247513      -0.353595         0.206234
# total_pop                  -0.455893       0.455274        -0.001008
# avg_income_per_cap          0.549244      -0.690814         0.325816
# private_work_%              1.000000      -0.869911        -0.180567
# public_work_%              -0.869911       1.000000        -0.320504
# self_employed_%            -0.180567      -0.320504         1.000000
# unemployment_%             -0.234267       0.281974        -0.151872
# zone_profitability          0.256746      -0.369639         0.224349
#
#                       unemployment_%  zone_profitability
# avg_usd_per_1/5_mile       -0.024897            0.318874
# avg_usd_per_minute         -0.009250           -0.048959
# number_of_trips_here       -0.044742            0.987927
# total_pop                  -0.024061           -0.127165
# avg_income_per_cap         -0.382300            0.442055
# private_work_%             -0.234267            0.256746
# public_work_%               0.281974           -0.369639
# self_employed_%            -0.151872            0.224349
# unemployment_%              1.000000           -0.050849
# zone_profitability         -0.050849            1.000000

# %%
sns.heatmap(df[CORR_COLS].corr())


plt.title('Pearson Correlation Metric For Employment Type')
plt.show()

# %% [markdown]
# ### Discuss the relationship between attributes of interest

# %% [markdown]
# ## Personal Checklist for Visualisations and Dashboards:
# 1. Your visualisation needs to tell a story.
# 2. It should be interpretable without being overly verbose.
# 3. The scale and axis need to make sense (and you can assume the reader knows the difference between a normal scale vs log scale).
# 4. The choice of visualisation needs to make sense:
#     - Line plot vs Bar chart with non-numerical categories
#     - Map plot with points vs clusters for each location
#     - Scatterplot vs Histogram plot to see distribution
#     - etc
# 5. Choice of colour scheme / alpha / size need to be easy on the eyes.
#
# At the end of the day, even if you think your visualisation is "pretty" or "beautiful", if a reader cannot understand it, then it is not a good visualisation.
#
# Let's go through an example on **pickup locations**.

# %% [markdown]
# ### Other Visualizations
# We recommend that you plot and look at these attributes in your own time using `matplotlib` and `seaborn`.
#
# Scatterplot of `fare_amount` vs `trip_amount`:
# - What's the relationship look like?
# - Why are there many values around 0?
#
#
# Histogram and distribution plot of `fare_amount`, `trip_amount`, `trip_distance`:
# - Is the distribution skewed?
# - Does a log transformation make the distribution nicer?
# - What outliers do we have?
# - What business rules should I be taking into account?
#
#
# Correlation Heatmap between attributes of relevance:
# - Which attributes should we choose? Remember, Pearson's correlation only applies to numerical features and assumes a linear relationship.
# - Does correlation imply causality?
#
# You may also apply relevant transformations where suitable i.e `log`. Just make sure you **state it clearly** in your figure caption or legend.
#
# A revision of skewness (in case you have forgotten and that's okay):
#
# <img src=https://mammothmemory.net/images/user/base/Maths/Statistics%20and%20probability/Standard%20deviation/skewed-distribution-graphs.c97bc76.jpg alt-text="skew" width=800px>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.corr())
# wow that's easy...

plt.title('Pearson Correlation Metric')
plt.show()
# ... but is it really that easy? read below!

# %% [markdown]
# Things to take note of:
# - `trip_distance` highly correlates with high tips, tolls and overall trip amount
# - `payment_type` seems to have some form of negative correlation with `tip_amount`. **Be careful as this is a discrete category.**
# - Having `VendorID`, `PULocationID`, `DOLocationID`, etc as features **is misleading**, why???
#
# **Important:** Only include numerical and ordinal features when computing the Pearson Correlation metric. You cannot compute the correlation between a category and numerical feature (i.e `VendorID` vs `payment_type` vs `trip_distance`).
#
# How about Locations? Does correlation work for it?

# %%
CORR_COLS = [
    "passenger_count", "trip_distance", "fare_amount", "extra", 
    "mta_tax", "tip_amount", "tolls_amount", "improvement_surcharge", 
    "total_amount", "airport_fee"
]

sns.heatmap(df[CORR_COLS].corr())

plt.title('Pearson Correlation Metric')
plt.show()

# %% [markdown]
# - If you're interested in calculating correlation between nominal and continuous data, here's a [great explanation](https://stats.stackexchange.com/questions/119835/correlation-between-a-nominal-iv-and-a-continuous-dv-variable/124618#124618).
# - Remember, you need to refer back to the data dictionary as well as the fare page: https://www1.nyc.gov/site/tlc/passengers/taxi-fare.page
#
# - You should especially take note of the fare page if you're looking to see how `RatecodeID` plays a role on the fare.

# %% [markdown]
# ## Plot relationships between features / attributes

# %% [markdown]
# ## Research Goal:
# ### - Which type of vehicle driver makes the most money per hour and why
# ### - Which periods of the year do vehicle drivers make the most money during and why (could use external datasets of when and where social events are occurring which increase taxi / fhv demand)
# ### - Which regions of NYC do vehicle drivers make the most money during and why
# ### - How can taxi / fhv drivers maximise tip amounts in general
# ### - When and where are traffic levels lowest during the year / day for NYC (requires external datasets)
#
# ### Could also go the passenger route
# ### - Which taxi / fhv service provides the cheapest service over the same distance
# ### - Which taxi / fhv service leads to the most pleasant experience (driver ratings, frequency of sharing with different passengers, wait times, etc.)
